# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import cv2
import os, shutil
import glob
from skimage.filters import gaussian
from skimage import img_as_ubyte
from PIL import Image, ImageFilter

# %%
import csv

with open("/content/gdrive/MyDrive/CyberAI/DesireVal.csv") as file_name:
    file_read = csv.reader(file_name)
    array = list(file_read)
 
print(array)
# Out:
# [['ILSVRC2012_val_00000214.JPEG'], ['ILSVRC2012_val_00000254.JPEG'], ['ILSVRC2012_val_00000288.JPEG'], ['ILSVRC2012_val_00000559.JPEG'], ['ILSVRC2012_val_00000595.JPEG'], ['ILSVRC2012_val_00000623.JPEG'], ['ILSVRC2012_val_00000700.JPEG'], ['ILSVRC2012_val_00001144.JPEG'], ['ILSVRC2012_val_00001153.JPEG'], ['ILSVRC2012_val_00001304.JPEG'], ['ILSVRC2012_val_00001320.JPEG'], ['ILSVRC2012_val_00001327.JPEG'], ['ILSVRC2012_val_00001382.JPEG'], ['ILSVRC2012_val_00001525.JPEG'], ['ILSVRC2012_val_00001631.JPEG'], ['ILSVRC2012_val_00001722.JPEG'], ['ILSVRC2012_val_00001729.JPEG'], ['ILSVRC2012_val_00001795.JPEG'], ['ILSVRC2012_val_00001859.JPEG'], ['ILSVRC2012_val_00001983.JPEG'], ['ILSVRC2012_val_00002120.JPEG'], ['ILSVRC2012_val_00002122.JPEG'], ['ILSVRC2012_val_00002162.JPEG'], ['ILSVRC2012_val_00002210.JPEG'], ['ILSVRC2012_val_00002434.JPEG'], ['ILSVRC2012_val_00002495.JPEG'], ['ILSVRC2012_val_00002520.JPEG'], ['ILSVRC2012_val_00002544.JPEG'], ['ILSVRC2012_val_00002593.JPEG'], ['ILSVRC201
# ...

# %%
count=0
print(array)

for root, dirs, files in os.walk("/content/gdrive/MyDrive/CyberAI/ILSVRC2012_img_val"):
  for a in files:
    temp= [a]
    if temp in array:
      count+=1
      print(temp)
      #shutil.move('/content/gdrive/MyDrive/CyberAI/ILSVRC2012_img_val/'+a, '/content/gdrive/MyDrive/CyberAI/DesiredVal')
print(count)
# Out:
# [['ILSVRC2012_val_00000214.JPEG'], ['ILSVRC2012_val_00000254.JPEG'], ['ILSVRC2012_val_00000288.JPEG'], ['ILSVRC2012_val_00000559.JPEG'], ['ILSVRC2012_val_00000595.JPEG'], ['ILSVRC2012_val_00000623.JPEG'], ['ILSVRC2012_val_00000700.JPEG'], ['ILSVRC2012_val_00001144.JPEG'], ['ILSVRC2012_val_00001153.JPEG'], ['ILSVRC2012_val_00001304.JPEG'], ['ILSVRC2012_val_00001320.JPEG'], ['ILSVRC2012_val_00001327.JPEG'], ['ILSVRC2012_val_00001382.JPEG'], ['ILSVRC2012_val_00001525.JPEG'], ['ILSVRC2012_val_00001631.JPEG'], ['ILSVRC2012_val_00001722.JPEG'], ['ILSVRC2012_val_00001729.JPEG'], ['ILSVRC2012_val_00001795.JPEG'], ['ILSVRC2012_val_00001859.JPEG'], ['ILSVRC2012_val_00001983.JPEG'], ['ILSVRC2012_val_00002120.JPEG'], ['ILSVRC2012_val_00002122.JPEG'], ['ILSVRC2012_val_00002162.JPEG'], ['ILSVRC2012_val_00002210.JPEG'], ['ILSVRC2012_val_00002434.JPEG'], ['ILSVRC2012_val_00002495.JPEG'], ['ILSVRC2012_val_00002520.JPEG'], ['ILSVRC2012_val_00002544.JPEG'], ['ILSVRC2012_val_00002593.JPEG'], ['ILSVRC201
# ...
